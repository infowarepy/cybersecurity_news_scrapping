# %%
from googlesearch import search
from bs4 import BeautifulSoup
# import utils
import pandas as pd
from datetime import datetime, timedelta
import requests
import string
API_KEY='01a425686ae74b939601e6adf09e9b7b' #rachitavya@gmail.com
# API_KEY='9b6d683a4f4646998e31fd51ecf8af2b' #rachitavya@outlook.com

# %% [markdown]
# # Everything API

# %%
def reduce_json(json_data, max_results):
    # Check if 'articles' key is present
    if 'articles' in json_data and json_data['totalResults'] > max_results:
        # Limit the number of articles to max_results
        json_data['articles'] = json_data['articles'][:max_results]
        json_data['totalResults'] = max_results
    else:
        reduce_json(json_data, max_results-1)
    
    return json_data

# %%
def get_date(days):
    today_date = datetime.now()
    new_days_ago = today_date - timedelta(days)
    new_days_ago_format = new_days_ago.strftime('%Y-%m-%d')
    return new_days_ago_format

# %%
json_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 json_data
#
# NameError: name 'json_data' is not defined

# %%
get_date(0)
# Out:
# '2023-11-29'

# %%
# url = ('https://newsapi.org/v2/everything?'
#        'q=india&'
#        'from=2023-10-23&'
#        'sortBy=popularity&'
#        'apiKey=01a425686ae74b939601e6adf09e9b7b')
# url=f'https://newsapi.org/v2/everything?q=cybersecurity+AND+india&from=2023-10-23&sortBy=popularity&apiKey={API_KEY}'
coutnry='france'
url=f'https://newsapi.org/v2/everything?q=cybersecurity+AND+{country}+AND+cyber&from={get_date(3)}&sortBy=popularity&apiKey={API_KEY}'

response = requests.get(url)
articles_data=reduce_json(response.json(),10)

# %%
articles_data['totalResults']
# Out:
# 10

# %%
articles=response.json()
len(articles)
# Out:
# 3

# %%
new=reduce_json(articles,4)

# %%
new
# Out:
# {'status': 'ok',
#  'totalResults': 4,
#  'articles': [{'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Emma Woollacott, Senior Contributor, \n Emma Woollacott, Senior Contributor\n https://www.forbes.com/sites/emmawoollacott/',
#    'title': 'U.S, U.K. And 16 Other Nations Agree AI Security Guidelines',
#    'description': 'Eighteen countries have signed an agreement on AI safety, based on the principle that it should be secure by design.',
#    'url': 'https://www.forbes.com/sites/emmawoollacott/2023/11/27/us-uk-and-16-other-nations-agree-ai-security-guidelines/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6564975e60f6bfc933dfffb9/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2023-11-27T13:20:23Z',
# ...

# %%
api_links=[]
for i,article in enumerate(articles_data['articles']):
    
    title=article['title']
    api_links.append(article['url'])

# %%
api_links
# Out:
# ['https://korben.info/cyber-management-school-master.html',
#  'https://www.forbes.com/sites/emmawoollacott/2023/11/27/us-uk-and-16-other-nations-agree-ai-security-guidelines/',
#  'https://www.forbes.com/sites/britneynguyen/2023/11/27/us-joins-17-other-countries-in-agreement-to-keep-ai-safe/',
#  'https://siliconangle.com/2023/11/27/u-s-u-k-leading-nations-reach-agreement-ai-safety/',
#  'https://www.theregister.com/2023/11/27/uks_global_guidance_leads_international/',
#  'https://www.globenewswire.com/news-release/2023/11/27/2785979/0/en/Remote-Work-Security-Market-Cloud-Security-Segment-Witnessed-Growth-At-A-Rapid-Rate-Reveals-InsightAce-Study.html',
#  'https://www.globenewswire.com/news-release/2023/11/27/2786061/0/en/Global-Digital-Transformation-Market-Size-To-Exceed-USD-10-571-7-Billion-By-2032-CAGR-of-23-4.html',
#  'https://www.globenewswire.com/news-release/2023/11/27/2786351/0/en/Global-Graph-Analytics-Size-to-Reach-USD-20-57-Billion-in-2032-Emergen-Research.html',
# ...

# %%
response.json()['articles'][0]['url']
# Out:
# 'https://www.bbc.co.uk/news/world-asia-india-67167036'

# %% [markdown]
# # Top-headlines

# %%
url=f'https://newsapi.org/v2/top-headlines?country=in&apiKey={API_KEY}&totalResults=100'
response = requests.get(url)

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 38,
#  'articles': [{'source': {'id': None, 'name': 'The Indian Express'},
#    'author': 'The Indian Express',
#    'title': 'Chandrayaan 3: Vikram lander generated ‘ejecta halo’ on lunar surface. What does it mean? - The Indian Express',
#    'description': None,
#    'url': 'https://indianexpress.com/article/technology/science/chandrayaan-3-vikram-ejecta-halo-on-lunar-surface-9004228/',
#    'urlToImage': None,
#    'publishedAt': '2023-10-29T06:12:27Z',
#    'content': None},
#   {'source': {'id': 'the-hindu', 'name': 'The Hindu'},
#    'author': 'The Hindu',
#    'title': 'One killed, several injured in explosion at a convention centre in Kalamassery - The Hindu',
#    'description': None,
#    'url': 'https://www.thehindu.com/news/national/kerala/people-killed-several-injured-in-explosion-at-a-convention-centre-in-kalamassery/article67472535.ece',
#    'urlToImage': None,
#    'publishedAt': '2023-10-29T05:48:00Z',
#    'content': None},
# ...

# %% [markdown]
# # Functions

# %%
def filter_final_news_links(links):
    lst = ['cybersecurity','cybersecurity-act','act','cyber','policy','information','strategies','attacks','threats','security']
    keyword_list = [i for i in lst if str(i) != 'nan']
    url = []
    list = []
    lnk = []
    for link in links:
        str1 = link.split("/")
        if str1[-1]=='':
            s = str1[-2].split('-')
            check = any(item in s for item in keyword_list)
            if check is True:
                lnk.append(link)
        else:
            s = str1[-1].split('-')
            check = any(item in s for item in keyword_list)
            if check is True:
                lnk.append(link)

    return lnk

# %%
def filter1(links,country_name):
    filter1_links = list()
    print('filter1_links=',filter1_links)
    https_links = [link for link in links if 'https://' in link.lower()] 
    print('https_links=',https_links)
    authentic_site_extension = extension_for_url(country_name)
    print("extension name : ",authentic_site_extension)
    com_ex = ['.gov','.org','.eu','itu']
    c_ex = [i for i in authentic_site_extension if i not in com_ex]
    print('c_ex',c_ex)
    print('length >>>' ,len(c_ex))
    if len(c_ex)<=0:
        c_ex = authentic_site_extension
        first_stage_filter = [link for i in authentic_site_extension for link in https_links if i.lower() in link.lower()]
        first_stage_filter = https_links if len(first_stage_filter) == 0 else first_stage_filter
        filter1_links = list(set(first_stage_filter))
    else:
        first_stage_filter = [link for i in authentic_site_extension for link in https_links if i.lower() in link.lower()]
        first_stage_filter = https_links if len(first_stage_filter) == 0 else first_stage_filter
        filter1_links = list(set(first_stage_filter))
    return filter1_links,c_ex

# %%
len(res[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 len(res[0])
#
# NameError: name 'res' is not defined

# %%
def extension_for_url(country):
    df = pd.read_csv("WebScrap.csv")
    key =[]
    for i in df['Country']:
        if country.replace(" ",'').lower() in i.lower().replace(" ",''):
            x = (df.loc[(df['Country'] == i )]).values.tolist()
            url_kwy = [i for i in x[0][1:] if str(i) != 'nan']
            key += url_kwy
    ke = list(set(key))
    return ke

# %%
def filter_sublinks(sublink_list,main_extension):
    df = pd.read_excel("Regulator.xlsx", sheet_name='keywords')
    keyword_list = [i for i in df['Url_keywords'].tolist() if str(i) != 'nan']
    filter2_sublinks = []
    for keyword in keyword_list:
        y = keyword.translate(str.maketrans('', '', string.punctuation))
        for each_sublink in sublink_list:
            if main_extension in each_sublink:
                 filter2_sublinks.append(each_sublink)            
            x = each_sublink.translate(str.maketrans('', '', string.punctuation))
            if y.lower() in x.lower():
                filter2_sublinks.append(each_sublink)
    filter2_sublinks = list(set(filter2_sublinks))
    return filter2_sublinks

# %%
def filter3(link_list): 
    l = ['linkedin','facebook','twitter','youtube','instagram','wiki','contact','yahoo','whatsapp','login','signin','unodc','cyberwiser.eu']
    q = [link for link in link_list if any(ext in link for ext in l)]
    links = [i for i in link_list if i not in q]
    return links

# %%
country_name='fajk'
query=f"cybersecurity news articles in \"{country_name}\" "# \" site:{source}"

# %%
print(query)
# Out:
# cybersecurity news articles in "fajk"

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\rachi\\anaconda3\\python.exe'

# %%
def extract_source(url):
    parsed_url = urlparse(url)
    source = parsed_url.netloc  # Get the domain or host part
    return source

# %%
#remove the social media urls
def filter3(link_list): 
    l = ['linkedin','facebook','twitter','youtube','instagram','wiki','contact','yahoo','whatsapp','login','signin','unodc','cyberwiser.eu']
    q = [link for link in link_list if any(ext in link for ext in l)]
    links = [i for i in link_list if i not in q]
    return links

# %%
from urllib.parse import urlparse
source=extract_source('https://igamingbusiness.com/tech-innovation/cybersecurity/netherlands-gambling-concerns/')
source
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 from urllib.parse import urlparse
# ----> 2 source=extract_source('https://igamingbusiness.com/tech-innovation/cybersecurity/netherlands-gambling-concerns/')
#       3 source
#
# NameError: name 'extract_source' is not defined

# %% [markdown]
# # Google search

# %%
links= ['https://www.privacyshield.gov/ps/article?id=Bulgaria-Safety-and-Security', 'https://cms-lawnow.com/en/ealerts/2018/11/bulgaria-adopts-new-cyber-security-act', 'https://www.trade.gov/country-commercial-guides/bulgaria-safety-and-security', 'https://bg.usembassy.gov/u-s-donates-cyber-defence-center-to-bulgaria-09-14-2023/', 'https://www.dataguidance.com/opinion/bulgaria-cybersecurity', 'https://e-gov.bg/wps/portal/agency-en/strategy-policy/security-aspects-digital-government', 'https://ccdcoe.org/library/strategy-and-governance/?category=cyber-security-strategies', 'https://cyberpolicyportal.org/states/bulgaria', 'https://www.itu.int/en/ITU-D/Regional-Presence/Europe/Documents/Events/2016/Cybersecurity%20Forum%20Bulgaria/Bulgaria_sharkov_todorov.pdf']

# %%
query='"germany" site:https://www.cshub.com/'

# %%
print(query)
# Out:
# "germany" site:https://www.cshub.com/

# %%
def extract_news(country,tld,source):
    query=f"cybersecurity news articles in \"{country}"#\" site:{source}"
#     query='"united kingdom" site:https://www.cshub.com/'
    print('>>>',query)
    news_links=[]
    c=0
    # for link in search(query, tld="co.in", num=1, stop=10, pause=2,tbs='qdr:w',user_agent='your bot 0.1'):
#     for link in search(query, num=20, stop=20, pause=5,tbs='qdr:w',user_agent='your bot 0.2',verify_ssl=False,country='nl'):
    for link in search(query, num=20, stop=20, pause=5,tbs='qdr:m',user_agent='your bot 0.2',country=tld):
        news_links.append(link)
        c=c+1
        print('Links fetched:',c,end='\r')

    return news_links

# %%
query
# Out:
# '"germany" site:https://www.cshub.com/'

# %%
search_res=search(query, num=20, stop=20, pause=5,tbs='qdr:m',user_agent='your bot 0.2',country=tld)

# %%
for i in search_res:
    print(i)
# Out:
# https://www.cshub.com/attacks/news/cyber-attack-forces-toyota-financial-services-systems-offline
# https://www.cshub.com/attacks/news/rhysida-ransomware-group-claims-crippling-british-library-cyber-attack
# https://www.cshub.com/attacks/news/blackcataplhv-ransomware-gang-files-sec-complaint-over-victims-undisclosed-breach
# https://www.cshub.com/attacks/news/lockbit-ransomware-affiliates-actively-exploiting-citrix-bleed-vulnerability
# https://www.cshub.com/attacks/news/data-breach-at-us-nuclear-energy-firm-exposes-sensitive-employee-information
# https://www.cshub.com/data/articles/safeguard-data-digital-age
# https://www.cshub.com/executive-decisions/news/businesses-pay-over-500000-for-top-cyber-security-talent

# %%
country='France'
tld='de'
source='fsisac.com'
news_links=extract_news(country=country,tld=tld,source=source)
# Out:
# >>> cybersecurity news articles in "France
# Links fetched: 20

# %%
news_links
# Out:
# ['https://www.lemonde.fr/en/cybersecurity/',
#  'https://www.diplomatie.gouv.fr/en/french-foreign-policy/security-disarmament-and-non-proliferation/news/2023/article/cybersecurity-adoption-of-the-french-resolution-for-a-un-action-program-3-nov',
#  'https://www.bloomberg.com/news/articles/2023-11-22/french-international-schools-agency-impacted-by-ransomware-hack',
#  'https://economictimes.indiatimes.com/tech/technology/top-french-court-upholds-uber-fine-for-illegal-service/articleshow/105570753.cms',
#  'https://www.scmagazine.com/news',
#  'https://www.mofa.go.jp/press/release/press5e_000077.html',
#  'https://www.euractiv.com/section/data-privacy/news/france-and-germany-increasingly-drift-apart-on-digital-sovereignty-of-cloud-sector/',
#  'https://financialpost.com/pmn/business-wire-news-releases-pmn/french-mod-challenge-thales-performs-a-successful-sovereign-ai-hack-and-presents-enhanced-security-solutions-for-military-and-civil-ai',
# ...

# %%
filter_final_news_links(api_links)
# Out:
# ['https://korben.info/cyber-management-school-master.html',
#  'https://www.forbes.com/sites/emmawoollacott/2023/11/27/us-uk-and-16-other-nations-agree-ai-security-guidelines/']

# %%
new_links=news_links+api_links
len(new_links)
# Out:
# 30

# %%
extension_for_url('france')
# Out:
# ['.fr', '.gov', '.org', '.eu']

# %%
filter1(api_links,'france')[0]
# Out:
# filter1_links= []
# ...

# %%
for news_link in news_links:
    n=0
    for ch in news_link:
        if ch=='/':
            n=n+1
    if n<4:
        continue
    print(news_link)
# Out:
# https://www.lemonde.fr/en/cybersecurity/
# https://www.diplomatie.gouv.fr/en/french-foreign-policy/security-disarmament-and-non-proliferation/news/2023/article/cybersecurity-adoption-of-the-french-resolution-for-a-un-action-program-3-nov
# https://www.bloomberg.com/news/articles/2023-11-22/french-international-schools-agency-impacted-by-ransomware-hack
# https://economictimes.indiatimes.com/tech/technology/top-french-court-upholds-uber-fine-for-illegal-service/articleshow/105570753.cms
# https://www.mofa.go.jp/press/release/press5e_000077.html
# https://www.euractiv.com/section/data-privacy/news/france-and-germany-increasingly-drift-apart-on-digital-sovereignty-of-cloud-sector/
# https://financialpost.com/pmn/business-wire-news-releases-pmn/french-mod-challenge-thales-performs-a-successful-sovereign-ai-hack-and-presents-enhanced-security-solutions-for-military-and-civil-ai
# https://www.bbc.com/news/topics/cz4pr2gd85qt
# ...

# %%
news_links_konbriefing=extract_news(country=country,tld=tld,source='konbriefing.com')
news_links_enisa=extract_news(country=country,tld=tld,source='enisa.europa.eu')
news_links=extract_news(country=country,tld=tld,source='')
# Out:
# >>> cybersecurity news articles in "France" site:konbriefing.com
# >>> cybersecurity news articles in "France" site:enisa.europa.eu
# >>> cybersecurity news articles in "France" site:
# Links fetched: 20

# %%
for i in news_links_konbriefing:
    print(i)
# Out:
# https://konbriefing.com/en-topics/cyber-attacks.html
# https://konbriefing.com/en-topics/cyber-attacks-universities.html
# https://konbriefing.com/en-topics/cyber-attacks-moveit-victim-list.html
# https://konbriefing.com/de-topics/cyber-angriffe-universitaeten.html
# https://konbriefing.com/de-topics/cyber-angriffe-oeffentliche-verwaltung.html

# %%
news_links_new=extract_news(country='United Kingdom',tld='uk',source='https://securityjournaluk.com/')
# Out:
# >>> cybersecurity news articles in "United Kingdom" site:https://securityjournaluk.com/
# Links fetched: 1

# %%
for i in news_links_new:
    print(i)
# Out:
# https://securityjournaluk.com/

# %%
filter1_links=filter1(links=links,country_name='Bulgaria')
# Out:
# filter1_links= []
# https_links= ['https://www.privacyshield.gov/ps/article?id=Bulgaria-Safety-and-Security', 'https://cms-lawnow.com/en/ealerts/2018/11/bulgaria-adopts-new-cyber-security-act', 'https://www.trade.gov/country-commercial-guides/bulgaria-safety-and-security', 'https://bg.usembassy.gov/u-s-donates-cyber-defence-center-to-bulgaria-09-14-2023/', 'https://www.dataguidance.com/opinion/bulgaria-cybersecurity', 'https://e-gov.bg/wps/portal/agency-en/strategy-policy/security-aspects-digital-government', 'https://ccdcoe.org/library/strategy-and-governance/?category=cyber-security-strategies', 'https://cyberpolicyportal.org/states/bulgaria', 'https://www.itu.int/en/ITU-D/Regional-Presence/Europe/Documents/Events/2016/Cybersecurity%20Forum%20Bulgaria/Bulgaria_sharkov_todorov.pdf']
# extension name :  ['.bg', '.org', '.eu', '.gov']
# c_ex ['.bg']
# length >>> 1

# %%
filter1_links
# Out:
# (['https://ccdcoe.org/library/strategy-and-governance/?category=cyber-security-strategies',
#   'https://www.privacyshield.gov/ps/article?id=Bulgaria-Safety-and-Security',
#   'https://bg.usembassy.gov/u-s-donates-cyber-defence-center-to-bulgaria-09-14-2023/',
#   'https://www.trade.gov/country-commercial-guides/bulgaria-safety-and-security',
#   'https://e-gov.bg/wps/portal/agency-en/strategy-policy/security-aspects-digital-government',
#   'https://cyberpolicyportal.org/states/bulgaria'],
#  ['.bg'])

# %%
izing_Cybersecurity_Regulations_2023.pdf', 'https://www.csis.org/programs/strategic-technologies-program', 'https://fipra.com/update/nato-and-a-360-approach-to-cyber-security/', 'https://www.whitecase.com/insight-our-thinking/tech-newsflash', 'https://www.brookings.edu/centers/strobe-talbott-center-for-security-strategy-and-technology/', 'https://www.atlanticcouncil.org/programs/scowcroft-center-for-strategy-and-security/', 'https://home.treasury.gov/policy-issues/international/g-7-and-g-20/g7-cyber-expert-group', 'https://www.chathamhouse.org/', 'https://atos.net/en-gb/united-kingdom', 'https://www.vodafone.com/about-vodafone/how-we-operate/our-strategy', 'https://www.aspi.org.au/', 'https://www.state.gov/subjects/cyber-security/', 'https://en.wikipedia.org/wiki/AUKUS']

# %%
news_links_nether
# Out:
# []

# %%
# Out:
# 157

# %%
for i in news_links: print(i)
# Out:
# https://igamingbusiness.com/tech-innovation/cybersecurity/netherlands-gambling-concerns/
# https://securitydelta.nl/news/overview/nl-missions-on-cyber-security-and-digitalisation-to-singapore
# https://www.igi-global.com/viewtitle.aspx?TitleId=332289&isxn=9781668488461
# https://www.dataguidance.com/news/netherlands-court-rules-criteo-unable-place-cookies
# https://www.igi-global.com/viewtitle.aspx?TitleId=332288&isxn=9781668488461
# https://press.un.org/en/2023/gadis3725.doc.htm
# https://www.clingendael.org/publication/dutch-niches-global-gateway-digital-domain
# https://www.nwo.nl/en/meetings/online-information-meeting-cybersecurity-for-digital-resilience
# https://hcss.nl/
# https://www.euractiv.com/section/cybersecurity/news/eu-parliament-set-to-request-involvement-in-cybersecurity-certification-schemes/
# https://www.dnb.nl/en/general-news/
# https://www.enisa.europa.eu/
# https://www.weforum.org/agenda/netherlands/
# https://www.politico.eu/country/netherlands/
# ...

# %%
for news_link in news_links:
    print(news_link)
# Out:
# https://www.dataguidance.com/news/singapore-csa-launches-cybersecurity-labelling-scheme-0
# https://securitydelta.nl/news/overview/nl-missions-on-cyber-security-and-digitalisation-to-singapore
# https://sbr.com.sg/information-technology/news/sg-launches-cybersecurity-training-programme
# https://opengovasia.com/elevating-singapores-cybersecurity-sector/
# https://press.un.org/en/2023/gadis3725.doc.htm
# https://www.csa.gov.sg/
# https://www.kroll.com/en/insights/publications/cyber/2023-sec-cybersecurity-rules
# https://www.channelnewsasia.com/world/artificial-intelligence-ai-promise-peril-cyber-threat-landscape-united-states-national-security-council-official-technology-election-biden-administration-cyber-strategy-3857596
# https://economictimes.indiatimes.com/tech/technology/cyber-experts-express-concern-about-data-security-in-india/articleshow/104626098.cms
# https://www.trendmicro.com/en_us/ciso/23/j/reduce-complexity-cybersecurity-consolidation.html

# %%
filter1_links,c_ex=filter1(news_links,'singapore')
filter2links = filter_sublinks(filter1_links,c_ex[0])
filter3links = filter3(filter2links)
# Out:
# extension name :  ['.org', '.gov.sg', '.gov']
# length >>> 1

# %%
filter2links = filter_sublinks(filter1_links[0],filter1_links[1][0])

# %%
filter2links
# Out:
# ['https://bg.usembassy.gov/u-s-donates-cyber-defence-center-to-bulgaria-09-14-2023/',
#  'https://www.trade.gov/country-commercial-guides/bulgaria-safety-and-security',
#  'https://www.privacyshield.gov/ps/article?id=Bulgaria-Safety-and-Security']

# 1       Singapore  ['https://www.dataguidance.com/news/singapore-...
# 2   United States  ['https://www.cisa.gov/news-events/news/cisa-a...
# 3          Turkey  ['https://www.trendmicro.com/en_hk/ciso/23/j/r...
# 4          Mexico  ['https://newsroom.accenture.com/news/accentur...
# 5     Switzerland  ['https://press.un.org/en/2023/gadis3725.doc.h...
# 6         Finland  ['https://jsis.washington.edu/news/analyzing-f...
# 7         Germany  ['https://www.dataguidance.com/news/germany-bm...
# 8         Iceland  ['https://www.fierceelectronics.com/electronic...
# 9           Italy  ['https://ciso.economictimes.indiatimes.com/ne...
# 10      Luxemborg                                                 []
# 11    Netherlands  ['https://igamingbusiness.com/tech-innovation/...
# 12       Portugal  ['https://www.prnewswire.com/sv/pressmeddeland...
# ...

# %%
latvia_links=log[log['Country']=='Latvia']

# %%
latvia_links
# Out:
#    Country                                              Links
# 26  Latvia  ['https://eng.lsm.lv/article/features/media/26...
# 27  Latvia  ['https://eng.lsm.lv/article/features/media/26...
# 28  Latvia  ['https://eng.lsm.lv/article/features/media/26...
# 29  Latvia  ['https://eng.lsm.lv/article/features/media/26...
# 30  Latvia  ['https://eng.lsm.lv/article/features/media/26...

# %%
latvia_data=list(latvia_links.Links)
for i in latvia_data:
    print(len(i))
# Out:
# 1472
# 237
# 237
# 2096
# 1977

# %%
for i in israel_new:
    print(i)
# Out:
# https://economictimes.indiatimes.com/opinion/et-editorial/israel-it-plus-one-is-india-ready/articleshow/104632817.cms
# https://www.securitymagazine.com/articles/100052-connecting-the-wars-intel-analysis-of-israel-hamas-and-russia-ukraine
# https://business.outlookindia.com/news/israel-hamas-war-indian-cyber-space-caught-in-the-crossfire-as-threat-groups-escalate-online-conflict
# https://www.csis.org/analysis/outlook-israels-military-campaign-against-hamas
# https://www.csis.org/analysis/experts-react-assessing-israeli-intelligence-and-potential-policy-failure
# https://finance.yahoo.com/news/hub-cyber-security-ltd-participates-135151116.html
# https://indianexpress.com/article/opinion/columns/hamas-attack-israel-technology-8993736/
# https://press.un.org/en/2023/gadis3725.doc.htm
# https://www.ft.com/content/e4e08e18-ad98-4c37-a620-570d3800dbea
# https://apcoworldwide.com/blog/corporate-boards-should-drive-cybersecurity-strategy/

# %%
new_links=news_links+api_links

# %%
filter3(filter1(new_links,'france')[0])
# Out:
# filter1_links= []
# ...

# %% [markdown]
# # DUMP

# %%
# url = "https://www.channelnewsasia.com/singapore/singapore-proactive-stance-cyber-threats-updated-national-strategy-2223536"
url='https://www.kcl.ac.uk/study/postgraduate-taught/courses/cyber-policy-strategy-ma'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    page_content = soup.prettify()
    print(page_content)
else:
    print("Failed to retrieve the webpage.")
# Out:
# <!DOCTYPE html>
# <html dir="ltr" itemscope="" itemtype="http://schema.org/" lang="en">
#  <head>
#   <meta content="null" data-react-helmet="true" name="description"/>
#   <meta content="King's College London" data-react-helmet="true" name="author"/>
#   <meta content="King's College London" data-react-helmet="true" property="og:site_name"/>
#   <meta content="Cyber Policy &amp; Strategy" data-react-helmet="true" property="og:title"/>
#   <meta content="null" data-react-helmet="true" property="og:description"/>
#   <meta content="https://www.kcl.ac.uk/study/postgraduate-taught/courses/cyber-policy-strategy-ma" data-react-helmet="true" property="og:url"/>
#   <meta content="https://www.kcl.ac.uk/newimages/sspp/Security/ws/feature-800-430/cyber-security.x362256f1.jpg?w=780&amp;h=470&amp;crop=780,440,0,15" data-react-helmet="true" property="og:image"/>
#   <meta content="KCL" data-react-helmet="true" property="og:image:alt"/>
# ...

# %%
response
# Out:
# <Response [403]>

# %%
newQuery=query.replace(' ','+')
url = f"https://www.google.com/search?q={newQuery}"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.1234.56 Safari/537.36 Edg/99.0.123.4"
}
response = requests.get(url, headers=headers)
blogs=[]

# %%
response
# Out:
# <Response [200]>

# %%
import requests
import random

url='https://newsapi.org/v2/top-headlines?country=in&category=cyber&apiKey=01a425686ae74b939601e6adf09e9b7b'
response=requests.get(url)

def getTechNews():
  res=random.sample(range(len(response.json()['articles'])),5)
  news_articles=[]
  for i in res:
    news_articles.append({'title':response.json()['articles'][i]['title'],'url':response.json()['articles'][i]['url']})
  
  return news_articles

print(getTechNews())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 15
#      11     news_articles.append({'title':response.json()['articles'][i]['title'],'url':response.json()['articles'][i]['url']})
#      13   return news_articles
# ---> 15 print(getTechNews())
#
# Cell In[69], line 8, in getTechNews()
#       7 def getTechNews():
# ----> 8   res=random.sample(range(len(response.json()['articles'])),5)
#       9   news_articles=[]
#      10   for i in res:
#
# File ~\anaconda3\lib\random.py:449, in Random.sample(self, population, k, counts)
#     447 randbelow = self._randbelow
#     448 if not 0 <= k <= n:
# --> 449     raise ValueError("Sample larger than population or is negative")
#     450 result = [None] * k
#     451 setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
def getBlogs(query,count):

    newQuery=query.replace(' ','+')
    
    url = f"https://www.google.com/search?q={newQuery}"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    response = requests.get(url, headers=headers)
    blogs=[]
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        results = soup.find_all('div', class_='g')

        if results:
            for result in results:
                title_element = result.find('h3')
                if title_element:
                    blogs.append({'title':title_element.text.strip()})
                    link_element = result.find('a')
                    if link_element:
                        blogs[len(blogs)-1]['link']=link_element['href']
                if len(blogs)==count:
                    break
    if response.status_code==429:
        return 'TOO MANY REQUESTS ERRO'
    return blogs

# %%
getBlogs(query=query,count=5)
# Out:
# [{'title': 'The Singapore Cybersecurity Strategy 2021',
#   'link': "https://www.csa.gov.sg/Tips-Resource/publications/2021/singapore-cybersecurity-strategy-2021#:~:text=The%20Singapore%20Cybersecurity%20Strategy%202021%20outlines%20Singapore's%20updated%20goals%20and,technologies%20are%20on%20the%20horizon."},
#  {'title': 'The Singapore Cybersecurity Strategy 2021',
#   'link': "https://www.csa.gov.sg/Tips-Resource/publications/2021/singapore-cybersecurity-strategy-2021#:~:text=The%20Singapore%20Cybersecurity%20Strategy%202021%20outlines%20Singapore's%20updated%20goals%20and,technologies%20are%20on%20the%20horizon."},
#  {'title': 'Singapore to take a more proactive stance on cyber threats ...',
#   'link': 'https://www.channelnewsasia.com/singapore/singapore-proactive-stance-cyber-threats-updated-national-strategy-2223536'},
#  {'title': 'Singapore rolls out national cybersecurity strategy',
# ...
